# %% [markdown]
# # World Bank GDP

# %%
# !pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\tinad\anaconda3\lib\site-packages (2.8.3)

# %%
# import dependencies

import pandas as pd
from sqlalchemy import create_engine
from bs4 import BeautifulSoup
import requests
import os
import pandas as pd
import json
import ast
from pprint import pprint

# %% [markdown]
# ### CSV Imports

# %%
#import the GDP csv

csv_file = "Resources/gdp.csv"
gdp_df = pd.read_csv(csv_file, encoding ="ISO-8859-1")
gdp_df.head()
# Out:
#          Country Abbreviation  GDP Ranking  US dollars
# 0  United States          USA            1  19,485,394
# 1          China          CHN            2  12,237,700
# 2          Japan          JPN            3   4,872,415
# 3        Germany          DEU            4   3,693,204
# 4          India          IND            5   2,650,725

# %%
#preview the count
gdp_df.count()
# Out:
# Country         200
# Abbreviation    200
# GDP Ranking     200
# US dollars      200
# dtype: int64

# %%
#get the name of the columns

gdp_df.columns
# Out:
# Index(['Country', 'Abbreviation', 'GDP Ranking', 'US dollars'], dtype='object')

# %%
#import the countries csv

ccsv_file = "Resources/countries.csv"
countries_df = pd.read_csv(ccsv_file, encoding ="ISO-8859-1")
countries_df.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area In Sq Mi  Population Density in Sq Mi  Net Migration  \
# 0         647500                         48.0          23.06
# 1          28748                        124.6          -4.93
# 2        2381740                         13.8          -0.39
# 3            199                        290.4         -20.71
# 4            468                        152.1           6.60
#
#    Infant Mortality per 1000 births  GDP Per Capita  Literacy Percent  \
# 0                            163.07           700.0              36.0
# 1                             21.52          4500.0              86.5
# 2                             31.00          6000.0              70.0
# 3                              9.27          8000.0              97.0
# 4                              4.05         19000.0             100.0
#
#    Phones per 1000  Arable Percent  Birthrate  Deathrate  Agriculture  \
# 0              3.2           12.13      46.60      20.34        0.380
# 1             71.2           21.09      15.11       5.22        0.232
# 2             78.1            3.22      17.14       4.61        0.101
# 3            259.5           10.00      22.46       3.27          NaN
# 4            497.2            2.22       8.71       6.25          NaN
#
#    Industry  Service
# 0     0.240    0.380
# 1     0.188    0.579
# 2     0.600    0.298
# 3       NaN      NaN
# 4       NaN      NaN

# %%
#preview the count

countries_df.count()
# Out:
# Country                             227
# Region                              227
# Population                          227
# Area In Sq Mi                       227
# Population Density in Sq Mi         227
# Net Migration                       224
# Infant Mortality per 1000 births    224
# GDP Per Capita                      226
# Literacy Percent                    209
# Phones per 1000                     223
# Arable Percent                      225
# Birthrate                           224
# Deathrate                           223
# Agriculture                         212
# Industry                            211
# Service                             212
# dtype: int64

# %%
#get the name of the columns

countries_df.columns
# Out:
# Index(['Country', 'Region', 'Population', 'Area In Sq Mi',
#        'Population Density in Sq Mi', 'Net Migration',
#        'Infant Mortality per 1000 births', 'GDP Per Capita',
#        'Literacy Percent', 'Phones per 1000', 'Arable Percent', 'Birthrate',
#        'Deathrate', 'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
#import the happiness csv

hcsv_file = "Resources/happiness.csv"
happiness_df = pd.read_csv(hcsv_file, encoding ="ISO-8859-1")
happiness_df.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Whisker High  Whisker Low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Per Capita GDP  Family Support Score  Health/Life Expectance Score  \
# 0        1.616463              1.533524                      0.796667
# 1        1.482383              1.551122                      0.792566
# 2        1.480633              1.610574                      0.833552
# 3        1.564980              1.516912                      0.858131
# 4        1.443572              1.540247                      0.809158
#
#    Freedom Score  Generosity Score  Trust In Government Score  \
# 0       0.635423          0.362012                   0.315964
# 1       0.626007          0.355280                   0.400770
# 2       0.627163          0.475540                   0.153527
# 3       0.620071          0.290549                   0.367007
# 4       0.617951          0.245483                   0.382612
#
#    Dystopia Residual Score
# 0                 2.277027
# 1                 2.313707
# 2                 2.322715
# 3                 2.276716
# 4                 2.430182

# %%
#preview the count

happiness_df.count()
# Out:
# Country                         155
# Happiness Rank                  155
# Happiness Score                 155
# Whisker High                    155
# Whisker Low                     155
# Per Capita GDP                  155
# Family Support Score            155
# Health/Life Expectance Score    155
# Freedom Score                   155
# Generosity Score                155
# Trust In Government Score       155
# Dystopia Residual Score         155
# dtype: int64

# %%
#get the name of the columns

happiness_df.columns
# Out:
# Index(['Country', 'Happiness Rank', 'Happiness Score', 'Whisker High',
#        'Whisker Low', 'Per Capita GDP', 'Family Support Score',
#        'Health/Life Expectance Score', 'Freedom Score', 'Generosity Score',
#        'Trust In Government Score', 'Dystopia Residual Score'],
#       dtype='object')

# %% [markdown]
# ### Creating New Data With Select Columns

# %%
#gdp_df

new_gdp_df = gdp_df[['Country', 'Abbreviation', 'GDP Ranking', 'US dollars']].copy()
new_gdp_df.head()
# Out:
#          Country Abbreviation  GDP Ranking  US dollars
# 0  United States          USA            1  19,485,394
# 1          China          CHN            2  12,237,700
# 2          Japan          JPN            3   4,872,415
# 3        Germany          DEU            4   3,693,204
# 4          India          IND            5   2,650,725

# %%
#countries_df

new_countries_df = countries_df[['Country', 'Region', 'Population', 'Area In Sq Mi',
       'Population Density in Sq Mi', 'Net Migration',
       'Infant Mortality per 1000 births', 'GDP Per Capita',
       'Literacy Percent', 'Phones per 1000', 'Arable Percent', 'Birthrate',
       'Deathrate', 'Agriculture', 'Industry', 'Service']].copy()
new_countries_df.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area In Sq Mi  Population Density in Sq Mi  Net Migration  \
# 0         647500                         48.0          23.06
# 1          28748                        124.6          -4.93
# 2        2381740                         13.8          -0.39
# 3            199                        290.4         -20.71
# 4            468                        152.1           6.60
#
#    Infant Mortality per 1000 births  GDP Per Capita  Literacy Percent  \
# 0                            163.07           700.0              36.0
# 1                             21.52          4500.0              86.5
# 2                             31.00          6000.0              70.0
# 3                              9.27          8000.0              97.0
# 4                              4.05         19000.0             100.0
#
#    Phones per 1000  Arable Percent  Birthrate  Deathrate  Agriculture  \
# 0              3.2           12.13      46.60      20.34        0.380
# 1             71.2           21.09      15.11       5.22        0.232
# 2             78.1            3.22      17.14       4.61        0.101
# 3            259.5           10.00      22.46       3.27          NaN
# 4            497.2            2.22       8.71       6.25          NaN
#
#    Industry  Service
# 0     0.240    0.380
# 1     0.188    0.579
# 2     0.600    0.298
# 3       NaN      NaN
# 4       NaN      NaN

# %%
#happiness_df

new_happiness_df = happiness_df[['Country', 'Happiness Rank', 'Happiness Score', 'Whisker High',
       'Whisker Low', 'Per Capita GDP', 'Family Support Score',
       'Health/Life Expectance Score', 'Freedom Score', 'Generosity Score',
       'Trust In Government Score', 'Dystopia Residual Score']].copy()
new_happiness_df.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Whisker High  Whisker Low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Per Capita GDP  Family Support Score  Health/Life Expectance Score  \
# 0        1.616463              1.533524                      0.796667
# 1        1.482383              1.551122                      0.792566
# 2        1.480633              1.610574                      0.833552
# 3        1.564980              1.516912                      0.858131
# 4        1.443572              1.540247                      0.809158
#
#    Freedom Score  Generosity Score  Trust In Government Score  \
# 0       0.635423          0.362012                   0.315964
# 1       0.626007          0.355280                   0.400770
# 2       0.627163          0.475540                   0.153527
# 3       0.620071          0.290549                   0.367007
# 4       0.617951          0.245483                   0.382612
#
#    Dystopia Residual Score
# 0                 2.277027
# 1                 2.313707
# 2                 2.322715
# 3                 2.276716
# 4                 2.430182

# %% [markdown]
# ### Store The Data Into a DataFrame

# %%
#store the data into a gdp_db

rds_connection_string = "postgres:postgres@localhost:5432/gdp_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
#check for tables
engine.table_names()
# Out:
# ['gdp', 'countries', 'happiness']

# %% [markdown]
# ### Load csv converted DataFrame into database

# %%
new_gdp_df.to_sql(name='gdp', con=engine, if_exists='append', index=False)

# %%
new_countries_df.to_sql(name='countries', con=engine, if_exists='append', index=False)

# %%
new_happiness_df.to_sql(name='happiness', con=engine, if_exists='append', index=False)

# %%
#confirm the gdp_data has been added to the table

pd.read_sql_query('select * from gdp', con=engine).head()
# Out:
#          Country Abbreviation  GDP Ranking  US dollars
# 0  United States          USA            1  19,485,394
# 1          China          CHN            2  12,237,700
# 2          Japan          JPN            3   4,872,415
# 3        Germany          DEU            4   3,693,204
# 4          India          IND            5   2,650,725

# %%
#confirm the countries_data has been added to the table

pd.read_sql_query('select * from countries', con=engine).head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area In Sq Mi  Population Density in Sq Mi  Net Migration  \
# 0         647500                         48.0          23.06
# 1          28748                        124.6          -4.93
# 2        2381740                         13.8          -0.39
# 3            199                        290.4         -20.71
# 4            468                        152.1           6.60
#
#    Infant Mortality per 1000 births  GDP Per Capita  Literacy Percent  \
# 0                            163.07           700.0              36.0
# 1                             21.52          4500.0              86.5
# 2                             31.00          6000.0              70.0
# 3                              9.27          8000.0              97.0
# 4                              4.05         19000.0             100.0
#
#    Phones per 1000  Arable Percent  Birthrate  Deathrate  Agriculture  \
# 0              3.2           12.13      46.60      20.34        0.380
# 1             71.2           21.09      15.11       5.22        0.232
# 2             78.1            3.22      17.14       4.61        0.101
# 3            259.5           10.00      22.46       3.27          NaN
# 4            497.2            2.22       8.71       6.25          NaN
#
#    Industry  Service
# 0     0.240    0.380
# 1     0.188    0.579
# 2     0.600    0.298
# 3       NaN      NaN
# 4       NaN      NaN

# %%
#confirm the happiness_data has been added to the table

pd.read_sql_query('select * from happiness', con=engine).head()
# Out:
#        Country  Happiness Rank  Happiness Score  Whisker High  Whisker Low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Per Capita GDP  Family Support Score  Health/Life Expectance Score  \
# 0        1.616463              1.533524                      0.796667
# 1        1.482383              1.551122                      0.792566
# 2        1.480633              1.610574                      0.833552
# 3        1.564980              1.516912                      0.858131
# 4        1.443572              1.540247                      0.809158
#
#    Freedom Score  Generosity Score  Trust In Government Score  \
# 0       0.635423          0.362012                   0.315964
# 1       0.626007          0.355280                   0.400770
# 2       0.627163          0.475540                   0.153527
# 3       0.620071          0.290549                   0.367007
# 4       0.617951          0.245483                   0.382612
#
#    Dystopia Residual Score
# 0                 2.277027
# 1                 2.313707
# 2                 2.322715
# 3                 2.276716
# 4                 2.430182
